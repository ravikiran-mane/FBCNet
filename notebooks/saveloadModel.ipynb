# %%
import torch

networkPath = "../output/bci42a/2023-11-20--22-41-132/FBCNet/"
checkpoint = torch.load(networkPath+"best_model.pth")
checkpoint
# Out:
# {'epoch': 30,
#  'model_state_dict': OrderedDict([('scb.0.weight', tensor([[[[-0.1278],
#                          [ 0.1244],
#                          [ 0.1214],
#                          ...,
#                          [ 0.0090],
#                          [ 0.2076],
#                          [-0.2897]]],
#
#
#                        [[[ 0.1119],
#                          [-0.0460],
#                          [-0.0717],
#                          ...,
#                          [ 0.4636],
#                          [ 0.1781],
#                          [-0.5222]]],
#
#
#                        [[[-0.1009],
#                          [-0.1021],
#                          [ 0.0017],
#                          ...,
#                          [ 0.0033],
#                          [-0.0838],
#                          [ 0.1403]]],
#
#
#                        ...,
#
#
#                        [[[ 0.0199],
#                          [ 0.0675],
#                          [ 0.0635],
# ...
